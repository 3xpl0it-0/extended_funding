# %% [markdown]
# for the next few notebooks im just going to mess around creating different features and seeing how they do against volatility scaled returns

# %%
# importing packages and data

import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np

df = pd.read_csv("extended_data.csv", 
dtype={0: float, 1: str, 2: float,  3: float,  4: float,  5: float,  6: float,  7: float,  8: int}
)

# fill missed funding periods with 0
df["funding"] = df["funding"].fillna(0)

# check number of assets
print(len(df["asset"].unique()))

#check if missing values remaining
nan_rows = df.isna().any(axis=1)
rows_with_nan = df[nan_rows]
print(rows_with_nan)
# Out:
# 57
# Empty DataFrame
# Columns: [timestamp, asset, open, high, low, close, volume, funding, funding inaccurate]
# Index: []

# %%
# define constants
RETURNS_LOOKBACK = 30
TARGET_VOLATILITY = 1/math.sqrt(365)
print(TARGET_VOLATILITY)
# Out:
# 0.052342392259021375

# %%
# making time readable
df["timestamp"] = pd.to_datetime(df["timestamp"], unit="ms")

# getting returns and return and funding volatility

# asset retuns
df["returns"] = (
    df.groupby("asset")["close"]
      .transform(lambda x: x.pct_change())
)

# asset returns inclusive of funding
df["returns_funding"] = df["returns"] - df["funding"]

# next day asset returns inclusive of funding
df["next_returns_funding"] = (
    df.groupby("asset")["returns_funding"]
      .shift(-1)
)

# asset returns and funding volatility
df["rolling_returns_funding_vol"] = (
    df.groupby("asset")["returns_funding"]
      .rolling(window=RETURNS_LOOKBACK)
      .std()
      .reset_index(level=0, drop=True)
)

# check work
df.iloc[50:56].head()
# Out:
#              timestamp         asset      open      high       low     close  \
# 50 2025-01-25 20:00:00  1000BONK-USD  0.029637  0.029813  0.028716  0.029260
# 51 2025-01-26 20:00:00  1000BONK-USD  0.029260  0.029260  0.024299  0.024748
# 52 2025-01-27 20:00:00  1000BONK-USD  0.024748  0.026785  0.024748  0.024954
# 53 2025-01-28 20:00:00  1000BONK-USD  0.024954  0.025741  0.022771  0.024913
# 54 2025-01-29 20:00:00  1000BONK-USD  0.024913  0.026438  0.023934  0.025254
#
#        volume   funding  funding inaccurate   returns  returns_funding  \
# 50   574900.0 -0.000037                  24 -0.012721        -0.012684
# 51  1239300.0 -0.000141                  24 -0.154204        -0.154063
# 52   982400.0 -0.000623                  24  0.008324         0.008947
# 53  1317900.0 -0.000022                  24 -0.001643        -0.001621
# 54  1091300.0 -0.000506                  24  0.013688         0.014194
#
#     next_returns_funding  rolling_returns_funding_vol
# 50             -0.154063                     0.075372
# 51              0.008947                     0.080323
# 52             -0.001621                     0.079880
# 53              0.014194                     0.079750
# 54             -0.012058                     0.079690

# %%
# creating funding signals

for i in [3, 5, 10, 15, 25, 40, 55]:
    
    df[f"funding_sma{i}"] = (
    df.groupby("asset")["funding"]
      .rolling(window=i)
      .mean()
      .reset_index(level=0, drop=True)
    )

    df[f"funding_sig{i}"] = df["funding"] - df[f"funding_sma{i}"]

    df[f"funding_sig{i}_scaled"] = (df["funding"] - df[f"funding_sma{i}"])/df[f"funding_sma{i}"]

# %%
# scaling returns and funding by volatility
df["returns_funding_volscaled"] = df["returns_funding"]*(TARGET_VOLATILITY/df["rolling_returns_funding_vol"])

# next day asset returns and funding scaled by volatility
df["next_returns_funding_volscaled"] = (
    df.groupby("asset")["returns_funding_volscaled"]
      .shift(-1)
)

# editing to remove what wont yet include a volatility scale and final day
df = df[df.groupby('asset').cumcount() > 55].copy()
df = df.groupby('asset').head(-1).copy()

#check if missing values remaining
nan_rows = df.isna().any(axis=1)
rows_with_nan = df[nan_rows]
print(rows_with_nan)
# Out:
#                timestamp    asset    open    high     low   close  volume  \
# 1355 2024-12-06 20:00:00  ADA-USD  1.2331  1.2331  1.2331  1.2331     0.0
# 1356 2024-12-07 20:00:00  ADA-USD  1.2331  1.2331  1.2331  1.2331     0.0
# 1357 2024-12-08 20:00:00  ADA-USD  1.2331  1.2331  1.2331  1.2331     0.0
# 1358 2024-12-09 20:00:00  ADA-USD  1.2331  1.2331  1.2331  1.2331     0.0
# 1359 2024-12-10 20:00:00  ADA-USD  1.2331  1.2331  1.2331  1.2331     0.0
# 1360 2024-12-11 20:00:00  ADA-USD  1.2331  1.2331  1.2331  1.2331     0.0
# 1361 2024-12-12 20:00:00  ADA-USD  1.2331  1.2331  1.2331  1.2331     0.0
# 1362 2024-12-13 20:00:00  ADA-USD  1.2331  1.2331  1.2331  1.2331     0.0
# 1363 2024-12-14 20:00:00  ADA-USD  1.2331  1.2331  1.2331  1.2331     0.0
# 1364 2024-12-15 20:00:00  ADA-USD  1.2331  1.2331  1.2331  1.2331     0.0
# 1365 2024-12-16 20:00:00  ADA-USD  1.2331  1.2331  1.2331  1.2331     0.0
#
#       funding  funding inaccurate  returns  ...  funding_sig25  \
# 1355      0.0                  24      0.0  ...      -0.000870
# 1356      0.0                  24      0.0  ...      -0.000895
# 1357      0.0                  24      0.0  ...      -0.000892
# 1358      0.0                  24      0.0  ...      -0.000819
# 1359      0.0                  24      0.0  ...      -0.000763
# 1360      0.0                  24      0.0  ...      -0.000703
# 1361      0.0                  24      0.0  ...      -0.000292
# 1362      0.0                  24      0.0  ...      -0.000275
# 1363      0.0                  24      0.0  ...      -0.000295
# 1364      0.0                  24      0.0  ...      -0.000307
# 1365      0.0                  24      0.0  ...      -0.000297
#
#       funding_sig25_scaled  funding_sma40  funding_sig40  \
# 1355                  -1.0       0.000557      -0.000557
# 1356                  -1.0       0.000557      -0.000557
# 1357                  -1.0       0.000552      -0.000552
# 1358                  -1.0       0.000546      -0.000546
# 1359                  -1.0       0.000532      -0.000532
# 1360                  -1.0       0.000532      -0.000532
# 1361                  -1.0       0.000532      -0.000532
# 1362                  -1.0       0.000535      -0.000535
# 1363                  -1.0       0.000538      -0.000538
# 1364                  -1.0       0.000542      -0.000542
# 1365                  -1.0       0.000547      -0.000547
#
#       funding_sig40_scaled  funding_sma55  funding_sig55  \
# 1355                  -1.0       0.000401      -0.000401
# 1356                  -1.0       0.000403      -0.000403
# 1357                  -1.0       0.000405      -0.000405
# 1358                  -1.0       0.000410      -0.000410
# 1359                  -1.0       0.000414      -0.000414
# 1360                  -1.0       0.000418      -0.000418
# 1361                  -1.0       0.000423      -0.000423
# 1362                  -1.0       0.000426      -0.000426
# 1363                  -1.0       0.000422      -0.000422
# 1364                  -1.0       0.000415      -0.000415
# 1365                  -1.0       0.000413      -0.000413
#
#       funding_sig55_scaled  returns_funding_volscaled  \
# 1355                  -1.0                        0.0
# 1356                  -1.0                        0.0
# 1357                  -1.0                        0.0
# 1358                  -1.0                        0.0
# 1359                  -1.0                        0.0
# 1360                  -1.0                        0.0
# 1361                  -1.0                        0.0
# 1362                  -1.0                        0.0
# 1363                  -1.0                        0.0
# 1364                  -1.0                        0.0
# 1365                  -1.0                        0.0
#
#       next_returns_funding_volscaled
# 1355                        0.000000
# 1356                        0.000000
# 1357                        0.000000
# 1358                        0.000000
# 1359                        0.000000
# 1360                        0.000000
# 1361                        0.000000
# 1362                        0.000000
# 1363                        0.000000
# 1364                        0.000000
# 1365                       -0.120332
#
# [11 rows x 36 columns]

# %%
idx_max = df["next_returns_funding_volscaled"].idxmax()
print(df.loc[idx_max])
idx_min = df["next_returns_funding_volscaled"].idxmin()
print(df.loc[idx_min])
# Out:
# timestamp                         2025-02-28 20:00:00
# asset                                         ADA-USD
# open                                            0.636
# high                                           0.6517
# low                                            0.6282
# close                                          0.6424
# volume                                         1560.0
# funding                                     -0.000301
# funding inaccurate                                 24
# returns                                      0.010063
# returns_funding                              0.010364
# next_returns_funding                         0.620888
# rolling_returns_funding_vol                  0.042673
# funding_sma3                                 0.000526
# funding_sig3                                -0.000827
# funding_sig3_scaled                         -1.572243
# funding_sma5                                 0.000498
# funding_sig5                                -0.000799
# funding_sig5_scaled                         -1.604904
# funding_sma10                               -0.000479
# funding_sig10                                0.000178
# funding_sig10_scaled                         -0.37187
# funding_sma15                               -0.000783
# funding_sig15                                0.000482
# funding_sig15_scaled                         -0.61545
# funding_sma25                               -0.001081
# funding_sig25                                 0.00078
# funding_sig25_scaled                        -0.721544
# funding_sma40                                -0.00085
# funding_sig40                                0.000549
# funding_sig40_scaled                        -0.645872
# funding_sma55                               -0.000591
# funding_sig55                                 0.00029
# funding_sig55_scaled                        -0.490427
# returns_funding_volscaled                    0.012712
# next_returns_funding_volscaled               0.264183
# Name: 1439, dtype: object
# timestamp                         2025-06-16 20:00:00
# asset                                          IP-USD
# open                                            3.586
# high                                           3.5997
# low                                            3.3125
# close                                          3.3284
# volume                                        27597.0
# funding                                     -0.000841
# funding inaccurate                                 24
# returns                                     -0.071835
# returns_funding                             -0.070994
# next_returns_funding                         -0.21711
# rolling_returns_funding_vol                  0.032414
# funding_sma3                                -0.000855
# funding_sig3                                 0.000014
# funding_sig3_scaled                         -0.015991
# funding_sma5                                -0.001091
# funding_sig5                                  0.00025
# funding_sig5_scaled                         -0.228865
# funding_sma10                               -0.001097
# funding_sig10                                0.000256
# funding_sig10_scaled                        -0.233294
# funding_sma15                               -0.001216
# funding_sig15                                0.000375
# funding_sig15_scaled                        -0.308653
# funding_sma25                                -0.00116
# funding_sig25                                0.000319
# funding_sig25_scaled                        -0.274975
# funding_sma40                                -0.00101
# funding_sig40                                0.000169
# funding_sig40_scaled                        -0.167347
# funding_sma55                               -0.000789
# funding_sig55                               -0.000052
# funding_sig55_scaled                          0.06598
# returns_funding_volscaled                   -0.114641
# next_returns_funding_volscaled              -0.229555
# Name: 5918, dtype: object

# %%
# create funding deciles
for i in [3, 5, 10, 15, 25, 40, 55]:
    df[f"funding_decile{i}"] = 0
    df[f"funding_decile{i}_scaled"] = 0

    # per day deciles across all assets
    df[f'funding_decile{i}'] = df.groupby('timestamp')[f'funding_sig{i}'] \
        .transform(lambda x: pd.qcut(x.rank(method='first'), 10, labels=False))
    
    df[f'funding_decile{i}_scaled'] = df.groupby('timestamp')[f'funding_sig{i}_scaled'] \
        .transform(lambda x: pd.qcut(x.rank(method='first'), 10, labels=False))

# check df
unique_times = df["timestamp"].unique()
#print(unique_times)
print(df[df["timestamp"] == unique_times[0]])
# Out:
#                 timestamp         asset           open           high  \
# 56    2025-01-31 20:00:00  1000BONK-USD       0.024936       0.025613
# 472   2025-01-31 20:00:00  1000PEPE-USD       0.014007       0.014258
# 762   2025-01-31 20:00:00  1000SHIB-USD       0.018872       0.019227
# 1411  2025-01-31 20:00:00       ADA-USD       0.945700       0.954300
# 1852  2025-01-31 20:00:00       ARB-USD       0.649000       0.651800
# 2271  2025-01-31 20:00:00      AVAX-USD      34.720000      35.070000
# 2909  2025-01-31 20:00:00       BNB-USD     679.200000     681.400000
# 3332  2025-01-31 20:00:00       BTC-USD  102375.600000  102753.100000
# 3780  2025-01-31 20:00:00      DOGE-USD       0.327960       0.330150
# 4475  2025-01-31 20:00:00       ETH-USD    3339.420000    3341.010000
# 5021  2025-01-31 20:00:00      GOAT-USD       0.203700       0.207700
# 6751  2025-01-31 20:00:00      LINK-USD      24.897000      25.905000
# 7157  2025-01-31 20:00:00       LTC-USD     126.150000     131.070000
# 7715  2025-01-31 20:00:00   MOODENG-USD       0.115780       0.117590
# 8121  2025-01-31 20:00:00      ONDO-USD       1.506000       1.506000
# 8527  2025-01-31 20:00:00        OP-USD       1.430000       1.453000
# 9186  2025-01-31 20:00:00    POPCAT-USD       0.329300       0.331900
# 9895  2025-01-31 20:00:00       SEI-USD       0.335000       0.335000
# 10312 2025-01-31 20:00:00       SOL-USD     232.370000     233.990000
# 10935 2025-01-31 20:00:00       SUI-USD       4.061500       4.110900
# 11357 2025-01-31 20:00:00       TIA-USD       4.336000       4.455000
# 12118 2025-01-31 20:00:00       TRX-USD       0.254180       0.256340
# 12873 2025-01-31 20:00:00       WIF-USD       1.167000       1.175000
# 13279 2025-01-31 20:00:00       WLD-USD       1.776000       1.807000
# 13756 2025-01-31 20:00:00       XRP-USD       3.033000       3.066000
#
#                  low          close        volume   funding  \
# 56          0.022493       0.022576  6.967000e+05 -0.000222
# 472         0.012828       0.012828  1.811000e+05 -0.000063
# 762         0.018068       0.018096  4.965000e+05 -0.000018
# 1411        0.910000       0.910000  8.270000e+02 -0.000261
# 1852        0.598700       0.600000  1.524400e+04 -0.000164
# 2271       32.810000      32.890000  2.766400e+02  0.000018
# 2909      660.800000     660.800000  2.480700e+01  0.001106
# 3332   101450.000000  101656.900000  3.263960e+00 -0.000005
# 3780        0.316570       0.316570  7.130000e+03 -0.000066
# 4475     3183.100000    3195.280000  2.102762e+02  0.001410
# 5021        0.169000       0.170400  1.724250e+06  0.000567
# 6751       23.539000      23.539000  4.697000e+02 -0.000020
# 7157      120.680000     120.680000  5.223000e+01 -0.000017
# 7715        0.097270       0.097650  6.053000e+04  0.000371
# 8121        1.390800       1.390800  5.689000e+03  0.000913
# 8527        1.373000       1.378000  3.092000e+03 -0.000149
# 9186        0.247500       0.249900  6.194000e+03  0.000920
# 9895        0.308000       0.308000  2.021000e+04 -0.000069
# 10312     221.270000     221.360000  2.187500e+02 -0.000445
# 10935       3.828800       3.828800  6.412000e+03 -0.000009
# 11357       3.999000       4.011000  6.803000e+02 -0.000004
# 12118       0.250320       0.250320  1.258000e+04 -0.000090
# 12873       1.059000       1.059000  8.920000e+02 -0.000231
# 13279       1.637000       1.644000  5.240000e+02 -0.000057
# 13756       2.916300       2.933500  8.063000e+03  0.000004
#
#        funding inaccurate   returns  ...  funding_decile10  \
# 56                     24 -0.094642  ...                 6
# 472                    24 -0.084172  ...                 3
# 762                    24 -0.041119  ...                 7
# 1411                   24 -0.037750  ...                 1
# 1852                   24 -0.075501  ...                 2
# 2271                   24 -0.052707  ...                 6
# 2909                   24 -0.027091  ...                 9
# 3332                   24 -0.007020  ...                 9
# 3780                   24 -0.034730  ...                 8
# 4475                   24 -0.043163  ...                 8
# 5021                   24 -0.163476  ...                 7
# 6751                   24 -0.054545  ...                 5
# 7157                   24 -0.043361  ...                 4
# 7715                   24 -0.156590  ...                 0
# 8121                   24 -0.076494  ...                 9
# 8527                   24 -0.036364  ...                 1
# 9186                   24 -0.241118  ...                 0
# 9895                   24 -0.080597  ...                 5
# 10312                  24 -0.047381  ...                 2
# 10935                  24 -0.057294  ...                 7
# 11357                  24 -0.074954  ...                 4
# 12118                  24 -0.015186  ...                 3
# 12873                  24 -0.092545  ...                 0
# 13279                  24 -0.074324  ...                 2
# 13756                  24 -0.032806  ...                 4
#
#        funding_decile10_scaled  funding_decile15  funding_decile15_scaled  \
# 56                         4.0                 2                        0
# 472                        5.0                 2                        4
# 762                        2.0                 7                        4
# 1411                       8.0                 1                        1
# 1852                       7.0                 2                        2
# 2271                       0.0                 9                        7
# 2909                       9.0                 5                        9
# 3332                       1.0                 8                        5
# 3780                       3.0                 8                        0
# 4475                       7.0                 9                        9
# 5021                       8.0                 0                        8
# 6751                       2.0                 6                        4
# 7157                       3.0                 3                        5
# 7715                       5.0                 0                        7
# 8121                       0.0                 9                        0
# 8527                       9.0                 4                        1
# 9186                       6.0                 0                        8
# 9895                       4.0                 7                        2
# 10312                      7.0                 5                        9
# 10935                      1.0                 4                        6
# 11357                      2.0                 6                        6
# 12118                      4.0                 3                        3
# 12873                      9.0                 1                        2
# 13279                      6.0                 4                        3
# 13756                      0.0                 7                        7
#
#        funding_decile25  funding_decile25_scaled  funding_decile40  \
# 56                    3                        9                 1
# 472                   2                        3                 2
# 762                   7                        0                 5
# 1411                  1                        0                 2
# 1852                  2                        1                 3
# 2271                  7                        7                 6
# 2909                  9                        8                 9
# 3332                  7                        2                 7
# 3780                  8                        7                 7
# 4475                  9                        8                 9
# 5021                  0                        6                 0
# 6751                  6                        3                 5
# 7157                  4                        4                 4
# 7715                  0                        5                 0
# 8121                  9                        2                 9
# 8527                  3                        0                 4
# 9186                  0                        6                 0
# 9895                  8                        7                 8
# 10312                 2                        9                 2
# 10935                 4                        4                 8
# 11357                 6                        4                 7
# 12118                 5                        9                 3
# 12873                 1                        1                 1
# 13279                 4                        2                 4
# 13756                 5                        5                 6
#
#        funding_decile40_scaled  funding_decile55  funding_decile55_scaled
# 56                           1                 1                        2
# 472                          4                 2                        4
# 762                          5                 6                        5
# 1411                         0                 1                        1
# 1852                         2                 3                        2
# 2271                         7                 7                        7
# 2909                         9                 9                        9
# 3332                         6                 7                        6
# 3780                         3                 7                        3
# 4475                         9                 9                        9
# 5021                         8                 0                        8
# 6751                         4                 4                        5
# 7157                         5                 3                        6
# 7715                         8                 0                        8
# 8121                         0                 9                        0
# 8527                         2                 4                        2
# 9186                         9                 0                        9
# 9895                         2                 8                        0
# 10312                        0                 2                        0
# 10935                        6                 8                        4
# 11357                        7                 6                        7
# 12118                        3                 5                        3
# 12873                        1                 2                        1
# 13279                        4                 4                        4
# 13756                        7                 5                        7
#
# [25 rows x 50 columns]

# %%
# scatter plot to gain initial intuiton
for i in [3, 5, 10, 15, 25, 40, 55]:

    plt.figure(figsize=(8,5))
    plt.scatter(
        df[f"funding_decile{i}"], 
        df["next_returns_funding_volscaled"], 
        alpha=0.3, 
        s=10
    )

    plt.xlabel(f"funding decile {i}")
    plt.ylabel("next day return and funding")
    plt.title(f"funding decile {i} vs next day return and funding (per day scatter)")
    plt.grid(True)

    plt.xlim(-0.5, 10.5)
    plt.xticks(range(0, 10))
    plt.show()

    plt.figure(figsize=(8,5))
    plt.scatter(
        df[f"funding_decile{i}_scaled"], 
        df["next_returns_funding_volscaled"], 
        alpha=0.3, 
        s=10
    )

    plt.xlabel(f"funding decile {i} scaled by sma")
    plt.ylabel("next day return and funding")
    plt.title(f"funding decile {i} scaled by sma vs next day return and funding (per day scatter)")
    plt.grid(True)

    plt.xlim(-0.5, 10.5)
    plt.xticks(range(0, 10))
    plt.show()

# %%
# decile plot to aim to see effects more clearly
for i in [3, 5, 10, 15, 25, 40, 55]:

    decile_means = df.groupby(f"funding_decile{i}")["next_returns_funding_volscaled"].mean()

    plt.figure(figsize=(8,5))
    plt.bar(decile_means.index, decile_means.values, color="skyblue")
    plt.xlabel(f"funding decile {i}")
    plt.ylabel("mean next day return and funding")
    plt.title(f"mean next day return and funding per funding decile from {i}")
    plt.xticks(decile_means.index)
    plt.grid(axis="y", linestyle="--", alpha=0.7)
    plt.show()

    decile_means = df.groupby(f"funding_decile{i}_scaled")["next_returns_funding_volscaled"].mean()

    plt.figure(figsize=(8,5))
    plt.bar(decile_means.index, decile_means.values, color="skyblue")
    plt.xlabel(f"funding decile {i} scaled by sma")
    plt.ylabel("mean next day return and funding")
    plt.title(f"mean next day return and funding per funding decile from {i} scaled by sma")
    plt.xticks(decile_means.index)
    plt.grid(axis="y", linestyle="--", alpha=0.7)
    plt.show()
